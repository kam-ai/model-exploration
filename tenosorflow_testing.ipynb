# %% [markdown]
# ## Create data

# %%
import numpy as np
from keras.datasets import mnist
from keras.utils import to_categorical


(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = np.expand_dims(X_train, axis=3)
X_test = np.expand_dims(X_test, axis=3)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Create model

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten

# Model from https://towardsdatascience.com/building-a-convolutional-neural-network-cnn-in-keras-329fbbadc5f5
model = Sequential()
model.add(Conv2D(64, kernel_size=3, activation='relu', input_shape=(28,28,1)))
model.add(Conv2D(32, kernel_size=3, activation='relu'))
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        18464
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                184330
# =================================================================
# Total params: 203,434
# Trainable params: 203,434
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train model

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test))
# Out:
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From c:\users\axel\kamai\pythonenvs\kamai\lib\site-packages\keras\backend\tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 60000/60000 [==============================] - 42s 694us/step - loss: 0.2249 - acc: 0.9515 - val_loss: 0.0777 - val_acc: 0.9784

# %% [markdown]
# ## Evaluate model

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
pred = model.predict(X_test)

# %%
for i in range(X_test.shape[0]):
    print('Below is %i' % np.argmax(pred[i]))
    plt.imshow(X_test[i, :, :,0])
    plt.show()
# Out:
# Below is 7
# Below is 2
# Below is 1
# Below is 0
# Below is 4
# Below is 1
# Below is 4
# Below is 9
# Below is 6
# Below is 9
# Below is 0
# Below is 6
# Below is 9
# Below is 0
# Below is 1
# Below is 5
# Below is 9
# Below is 7
# Below is 3
# Below is 4
# Below is 9
# Below is 6
# Below is 6
# Below is 5
# Below is 4
# Below is 0
# Below is 7
# Below is 4
# Below is 0
# Below is 1
# Below is 3
# Below is 1
# Below is 3
# Below is 4
# Below is 7
# Below is 2
# Below is 7
# Below is 1
# Below is 2
# Below is 1
# Below is 1
# Below is 7
# Below is 4
# Below is 2
# Below is 3
# Below is 5
# Below is 1
# Below is 2
# Below is 4
# Below is 4
# Below is 6
# Below is 3
# Below is 5
# Below is 5
# Below is 6
# Below is 0
# Below is 4
# Below is 1
# Below is 9
# Below is 5
# Below is 7
# Below is 8
# Below is 9
# Below is 3
# Below is 7
# Below is 4
# Below is 6
# Below is 4
# Below is 3
# Below is 0
# Below is 7
# Below is 0
# Below is 2
# Below is 9
# Below is 1
# Below is 7
# Below is 3
# Below is 2
# Below is 9
# Below is 7
# Below is 7
# Below is 6
# Below is 2
# Below is 7
# Below is 8
# Below is 4
# Below is 7
# Below is 3
# Below is 6
# Below is 1
# Below is 3
# Below is 6
# Below is 9
# Below is 3
# Below is 1
# Below is 4
# Below is 1
# Below is 7
# Below is 6
# Below is 9
# Below is 6
# Below is 0
# Below is 5
# Below is 4
# Below is 9
# Below is 9
# Below is 2
# Below is 1
# Below is 9
# Below is 4
# Below is 8
# Below is 7
# Below is 3
# Below is 9
# Below is 7
# Below is 4
# Below is 4
# Below is 4
# Below is 9
# Below is 2
# Below is 5
# Below is 4
# Below is 7
# Below is 6
# Below is 7
# Below is 9
# Below is 0
# Below is 5
# Below is 8
# Below is 5
# Below is 6
# Below is 6
# Below is 5
# Below is 7
# Below is 8
# Below is 1
# Below is 0
# Below is 1
# Below is 6
# Below is 4
# Below is 6
# Below is 7
# Below is 3
# Below is 1
# Below is 7
# Below is 1
# Below is 8
# Below is 2
# Below is 0
# Below is 2
# Below is 9
# Below is 8
# Below is 5
# Below is 5
# Below is 1
# Below is 5
# Below is 6
# Below is 0
# Below is 3
# Below is 4
# Below is 4
# Below is 6
# Below is 5
# Below is 4
# Below is 6
# Below is 5
# Below is 4
# Below is 5
# Below is 1
# Below is 4
# Below is 4
# Below is 7
# Below is 2
# Below is 3
# Below is 2
# Below is 7
# Below is 1
# Below is 8
# Below is 1
# Below is 8
# Below is 1
# Below is 8
# Below is 5
# Below is 0
# Below is 8
# Below is 9
# Below is 2
# Below is 5
# Below is 0
# Below is 1
# Below is 1
# Below is 1
# Below is 0
# Below is 9
# Below is 0
# Below is 3
# Below is 1
# Below is 6
# Below is 4
# Below is 2
# Below is 3
# Below is 6
# Below is 1
# Below is 1
# Below is 1
# Below is 3
# Below is 9
# Below is 5
# Below is 2
# Below is 9
